# %%
from cuota.data_classes.spanish_tax_rules import SpanishAutonomoModel, SpanishRegimenGeneralModel
model = SpanishAutonomoModel(2024)

# %%
sample = model.sample()

# %%
sample.columns
# Out:
# Index(['Social Security', 'Income Tax', 'total payable', 'take home',
#        'effective rate', 'marginal rate'],
#       dtype='object')

# %%
sample[['Social Security', 'Income Tax', 'total payable', 'take home']].plot()
# Out:
# <Axes: >

# %%
sample[['effective rate']].plot()
# Out:
# <Axes: >
